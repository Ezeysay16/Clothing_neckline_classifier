# %%
import numpy as np
import pandas as pd
import cv2
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from os.path import isfile, join
from os import listdir
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import load_model


model_oversampling = load_model('/content/drive/MyDrive/Neckline_Model_Oversampling.h5')
mobel_mb_oversampling = load_model('/content/drive/MyDrive/Neckline_MobileNet_Oversampling.h5')
mobel_res_oversampling = load_model('/content/drive/MyDrive/Neckline_ResNet50_Oversampling.h5')

mobel_weight = load_model('/content/drive/MyDrive/Neckline_model_classweight.h5')
mobel_mb_weight = load_model('/content/drive/MyDrive/Neckline_MobileNet_classweight.h5')
mobel_res_weight = load_model('/content/drive/MyDrive/Neckline_Resnet50_classweight.h5')

# %%
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

img_path1 = '/content/drive/MyDrive/4856_2.webp'
img = image.load_img(img_path1, target_size=(224, 224))
img_array1 = image.img_to_array(img)
img_array1 = np.expand_dims(img_array1, axis=0)

img_path2 = '/content/drive/MyDrive/15084221AE_11_f.jpg'
img = image.load_img(img_path2, target_size=(224, 224))
img_array2 = image.img_to_array(img)
img_array2 = np.expand_dims(img_array2, axis=0)

# %%
image1 = cv2.imread(img_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb1)

class_labels = ["round", "scoop", "v-neck"]

predictions1 = model_oversampling.predict(img_array1)
for i in range(3):
    print(f"{i + 1}: {class_labels[i]} - Probability: {predictions1[0][i]}")
max_class_index = np.argmax(predictions1)
max_class_label = class_labels[max_class_index]
max_probability = predictions1[0][max_class_index]
print(f"Predicted Class: {max_class_label}")
print(f"Probability: {max_probability}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1: round - Probability: 0.0
# 2: scoop - Probability: 1.0
# 3: v-neck - Probability: 0.0
# Predicted Class: scoop
# Probability: 1.0

# %%
image1 = cv2.imread(img_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb1)

predictions2 = mobel_mb_oversampling.predict(img_array1)
for i in range(3):
    print(f"{i + 1}: {class_labels[i]} - Probability: {predictions2[0][i]}")
max_class_index = np.argmax(predictions2)
max_class_label = class_labels[max_class_index]
max_probability = predictions2[0][max_class_index]
print(f"Predicted Class: {max_class_label}")
print(f"Probability: {max_probability}")
# Out:
# 1/1 [==============================] - 0s 98ms/step
# 1: round - Probability: 1.1233720215386711e-05
# 2: scoop - Probability: 0.9605857729911804
# 3: v-neck - Probability: 0.03940306976437569
# Predicted Class: scoop
# Probability: 0.9605857729911804

# %%
image1 = cv2.imread(img_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb1)

predictions3 = mobel_res_oversampling.predict(img_array1)
for i in range(3):
    print(f"{i + 1}: {class_labels[i]} - Probability: {predictions3[0][i]}")
max_class_index = np.argmax(predictions3)
max_class_label = class_labels[max_class_index]
max_probability = predictions3[0][max_class_index]
print(f"Predicted Class: {max_class_label}")
print(f"Probability: {max_probability}")
# Out:
# 1/1 [==============================] - 6s 6s/step
# 1: round - Probability: 0.13427281379699707
# 2: scoop - Probability: 0.8240845799446106
# 3: v-neck - Probability: 0.04164259508252144
# Predicted Class: scoop
# Probability: 0.8240845799446106

# %%
image1 = cv2.imread(img_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb1)

predictions4 = mobel_weight.predict(img_array1)
for i in range(3):
    print(f"{i + 1}: {class_labels[i]} - Probability: {predictions4[0][i]}")
max_class_index = np.argmax(predictions4)
max_class_label = class_labels[max_class_index]
max_probability = predictions4[0][max_class_index]
print(f"Predicted Class: {max_class_label}")
print(f"Probability: {max_probability}")
# Out:
# 1/1 [==============================] - 1s 715ms/step
# 1: round - Probability: 0.0
# 2: scoop - Probability: 1.0
# 3: v-neck - Probability: 0.0
# Predicted Class: scoop
# Probability: 1.0

# %%
image1 = cv2.imread(img_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb1)
predictions5 = mobel_mb_weight.predict(img_array1)
for i in range(3):
    print(f"{i + 1}: {class_labels[i]} - Probability: {predictions5[0][i]}")
max_class_index = np.argmax(predictions5)
max_class_label = class_labels[max_class_index]
max_probability = predictions5[0][max_class_index]
print(f"Predicted Class: {max_class_label}")
print(f"Probability: {max_probability}")
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b18d0620790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 1: round - Probability: 0.12412861734628677
# 2: scoop - Probability: 0.124798484146595
# 3: v-neck - Probability: 0.7510729432106018
# Predicted Class: v-neck
# Probability: 0.7510729432106018

# %%
image1 = cv2.imread(img_path1)
image_rgb1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb1)
predictions6 = mobel_res_weight.predict(img_array1)
for i in range(3):
    print(f"{i + 1}: {class_labels[i]} - Probability: {predictions6[0][i]}")
max_class_index = np.argmax(predictions6)
max_class_label = class_labels[max_class_index]
max_probability = predictions6[0][max_class_index]
print(f"Predicted Class: {max_class_label}")
print(f"Probability: {max_probability}")
# Out:
# WARNING:tensorflow:6 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b18d0566320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 2s 2s/step
# 1: round - Probability: 0.14731688797473907
# 2: scoop - Probability: 0.652114987373352
# 3: v-neck - Probability: 0.2005680352449417
# Predicted Class: scoop
# Probability: 0.652114987373352
